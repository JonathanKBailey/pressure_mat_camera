# %%
import os
import datetime
import pandas as pd
import numpy as np

# %%
base_path = 'Work Folders\Desktop\Infra Red camera data'
sync1_path = os.path.join(base_path, 'First Sync Test 14_05')

# %%
os.path.getctime(sync1_path)
# Out:
# 1715689450.1515546

# %%
for f in os.listdir(sync1_path):
    fp = os.path.join(sync1_path, f)
    if os.path.isfile(fp):
        tm = os.path.getctime(fp)
        print(f, tm, datetime.datetime.fromtimestamp(tm))
# Out:
# frame_ContDrc_0.csv 1715690614.6603217 2024-05-14 13:43:34.660322
# frame_ContDrc_1.csv 1715690614.7236905 2024-05-14 13:43:34.723691
# frame_ContDrc_10.csv 1715690615.9931133 2024-05-14 13:43:35.993113
# frame_ContDrc_100.csv 1715690852.4261014 2024-05-14 13:47:32.426101
# frame_ContDrc_101.csv 1715690852.537779 2024-05-14 13:47:32.537779
# frame_ContDrc_102.csv 1715690852.6875722 2024-05-14 13:47:32.687572
# frame_ContDrc_103.csv 1715690852.8520248 2024-05-14 13:47:32.852025
# frame_ContDrc_104.csv 1715690852.9587257 2024-05-14 13:47:32.958726
# frame_ContDrc_105.csv 1715690853.0659406 2024-05-14 13:47:33.065941
# frame_ContDrc_106.csv 1715690853.2165625 2024-05-14 13:47:33.216563
# frame_ContDrc_107.csv 1715690853.410055 2024-05-14 13:47:33.410055
# frame_ContDrc_108.csv 1715690853.5559566 2024-05-14 13:47:33.555957
# frame_ContDrc_109.csv 1715690853.7125497 2024-05-14 13:47:33.712550
# frame_ContDrc_11.csv 1715690616.1383255 2024-05-14 13:43:36.138325
# ...
